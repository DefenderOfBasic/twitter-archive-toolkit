# %%
import json 

username = 'defenderofbasic'
with open(f'../frontend/public/archives/{username}.json', 'r') as f:
    data = json.load(f)

data
# Out:
# {'upload-options': {'keepPrivate': False,
#   'uploadLikes': True,
#   'startDate': '2023-07-18T13:01:44.000Z',
#   'endDate': '2024-11-19T18:15:48.000Z'},
#  'profile': [{'profile': {'description': {'bio': 'Self funding open source memetic research. See research statement & support my work: https://t.co/zDlct7w2nZ',
#      'website': 'https://t.co/XqjxHtHYOu',
#      'location': 'Upstate NY'},
#     'avatarMediaUrl': 'https://pbs.twimg.com/profile_images/1784246094085443584/2qFrK_bU.jpg',
#     'headerMediaUrl': 'https://pbs.twimg.com/profile_banners/1680757426889342977/1689949048'}}],
#  'account': [{'account': {'createdVia': 'oauth:3033300',
#     'username': 'DefenderOfBasic',
#     'accountId': '1680757426889342977',
#     'createdAt': '2023-07-17T01:53:20.404Z',
#     'accountDisplayName': 'Defender'}}],
#  'tweets': [{'tweet': {'edit_info': {'initial': {'editTweetIds': ['1858937235288322214'],
#       'editableUntil': '2024-11-19T19:15:48.000Z',
#       'editsRemaining': '5',
# ...
